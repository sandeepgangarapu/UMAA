# %%
import pymalts
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(0)
sns.set()

# %%
#

# %%
df = pd.read_csv('files/input_malts.csv',index_col=0)

# %%
print(df.shape)
df.head()
# Out:
# (477987, 31)
#            UMN_event  UMN_member  UMN_donor  UMN_volun  UMN_inform  \
# ID_DEMO
# 100000125        0.0         0.0   0.000000        0.0    0.000000
# 100000250        0.0         0.0   0.000000        0.0    3.333333
# 100000295        0.0         1.5   0.000000        0.0    1.500000
# 100000304        0.0         0.0   0.666667        0.0    3.666667
# 100000307        0.0         0.0   0.000000        0.0    1.000000
#
#            UMN_loyalty  UMN_avg_Annual_score_5_years  Learning_emails  \
# ID_DEMO
# 100000125          0.0                      0.000000              0.0
# 100000250          0.0                      3.333333              0.0
# 100000295          0.0                      3.000000              0.0
# 100000304          0.0                      4.333333              0.0
# 100000307          0.0                      1.000000              0.0
#
#            Legislature_emails  Social_emails  ...  AGE  IN_TC_METRO_AREA  \
# ...

# %% [markdown]
# ### Setting up the model for learning the distance metric.
#
# Variable name for the outcome variable: 'outcome'.
# Variable name for the treatment variable: 'treated'
# Data is assigned to python variable d

# %%
m = pymalts.malts_mf(outcome='outcome', treatment='outcome', data=df) # running MALTS with default setting
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-00073809e5e4> in <module>
# ----> 1 m = pymalts.malts_mf( outcome='outcome', treatment='outcome', data=df) # running MALTS with default setting
#
# ~\AppData\Local\Continuum\anaconda3\envs\bandits\lib\site-packages\pymalts\__init__.py in __init__(self, outcome, treatment, data, discrete, C, k_tr, k_est, estimator, smooth_cate, reweight, n_splits, n_repeats, output_format)
#     264         self.MG_list = []
#     265         self.CATE_df = pd.DataFrame()
# --> 266         N = np.zeros((data.shape[0],data.shape[0]))
#     267         self.MG_matrix = pd.DataFrame(N, columns=data.index, index=data.index)
#     268
#
# MemoryError: Unable to allocate 1.66 TiB for an array with shape (477987, 477987) and data type float64
